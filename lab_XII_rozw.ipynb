# %% [markdown]
# # Automatyczne pozyskiwanie danych
# ### Tomasz Rodak
# ## Lab XII
#
# 2020/2021, semestr letni
#
# ---
#
# ## 1.
#
# Utwórz dokument typu *csv* lub *json* z rankingiem uniwersytetów.
#
# ### 1.1
#
# Pobierz ranking ze strony
# ```http
# https://roundranking.com/ranking/world-university-rankings.html#world-2021
# ```
#
# Wynik powinien zawierać przynajmniej te kolumny, które pokazują się bezpośrednio na stronie (poza flagą). Wejście w link danego uniwersytetu daje dodatkową serię informacji: rok założenia, liczba studentów, wielkość kadry itp. Zadanie możesz rozszerzyć o pobranie i tych informacji.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://roundranking.com/ranking/world-university-rankings.html#world-2021'

r=requests.get(url)
r
# Out:
# <Response [200]>

# %% [markdown]
# czy stanford znajduje sie w tekscie strony?

# %%
'Stanford' in r.text.lower()
# Out:
# False

# %%
len(r.text)
# Out:
# 18457

# %%
len(r.content)
# Out:
# 18483

# %% [markdown]
# ctr+w -> skrót do `pokaż źródło`

# %%
zupa=BeautifulSoup(r.content,'html.parser')

# %%
print(zupa)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <base href="https://roundranking.com/ranking/world-university-rankings.html?year=2020"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="round, university, ranking, rur" name="keywords"/>
# <meta content="Super User" name="author"/>
# <meta content="Round University Ranking RUR is a world university ranking, assessing effectiveness of leading universities in the world. " name="description"/>
# <meta content="Joomla! - Open Source Content Management" name="generator"/>
# <title>World University Rankings</title>
# <link href="/templates/rur/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="/templates/rur/css/bootstrap.min.css?v=202106091623242852" rel="stylesheet" type="text/css"/>
# <link href="/templates/rur/css/all17.css?v=202106091623242852" rel="stylesheet" type="text/css"/>
# ...

# %%
zupa.find(class_='tbody')

# %% [markdown]
# Tabela przy użyciu _selenium_

# %% [markdown]
# from selenium import webdriver
# import pandas as pd
#
# def drivera
#
# driver.maximize_window()
# driver.get(url)

# %% [markdown]
# F12 -> `network`, kopiujemy xpath calej tabeli

# %% [markdown]
# tbl=driver.find_element_by_xpath()
# tblAtrrList=tbl.get_attribute('outerHTML')
# print(tblAtrr)

# %%
df=tblAtrrList[0]

# %%
df[df.University.str.contains('Warsaw')]

# %%
df.isna().sum()

# %%
df.shape

# %%
df.tail()

# %%
nagrac do pliku!

# %%
driver.close()

# %% [markdown]
# ### 1.2
#
#
# Pobierz ranking ze strony
# ```http
# https://www.shanghairanking.com/rankings/arwu/2020
# ```
# Również i to zadanie możesz rozszerzyć o dodatkowe wpisy, analogicznie do 1.1

# %%
url2='https://www.shanghairanking.com/rankings/arwu/2020'

r2=requests.get(url2)
r2
# Out:
# <Response [200]>

# %%
zupa2=BeautifulSoup(r2.content,'html.parser')

# %% [markdown]
# nie mamy jak wykonac requests.get, bo zmnieniając numer strony adres strony się nie zmnienia, więc szeregowe operacje odpadają :(

# %%
nazwy=zupa2.find(class_='univ-name')

# %% [markdown]
# ### prze selenium

# %%
import pandas as pd
from selenium import webdriver
import time

url2='https://www.shanghairanking.com/rankings/arwu/2020'

# %%
driver=webdriver.Firefox(executable_path=...)
driver.maximize_window()

# %%
driver.get(url2)

while True:
    next_btn=driver.find_element_by_class_name('ant-pagination-next')
    
    if 'ant-pagination-disabled' in buttonNext.get_attribute('outerHTML'):
        break
    time.sleep(1)
    next_btn.click()
#/html/body/div/div/div/div[2]/div/div[2]/div/div[1]/div/ul/li[9]/a/i/svg

# %%
_.get_attribute('outerHTML')

# %%
table_html=driver.find_element_by_class('rk-table').get_attribute('outerHTML')

# %% [markdown]
# print(_) # - to ostatni output

# %%
pd.read_html(table_html)
